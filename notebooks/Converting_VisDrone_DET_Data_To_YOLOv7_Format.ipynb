# %% [markdown]
# ## Step-1: Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Step-2: Download VisDrone DET Dataset from Google Drive

# %%
# %%time
# %%bash
if [ -d VisDrone]
then
  echo "data already exists"
else 
  mkdir -p VisDrone
  unzip -d VisDrone drive/MyDrive/Deepak/FourthBrain/MLOps_Course/CapstoneProject/TrainYOLOv7/data/DET_data/VisDrone2019-DET-val.zip
  unzip -d VisDrone/VisDrone2019-DET-test-dev drive/MyDrive/Deepak/FourthBrain/MLOps_Course/CapstoneProject/TrainYOLOv7/data/DET_data/VisDrone2019-DET-test-dev.zip
  unzip -d VisDrone drive/MyDrive/Deepak/FourthBrain/MLOps_Course/CapstoneProject/TrainYOLOv7/data/DET_data/VisDrone2019-DET-train.zip
  # unzip -d VisDrone drive/MyDrive/Deepak/FourthBrain/MLOps_Course/CapstoneProject/TrainYOLOv7/data/DET_data/VisDrone2019-DET-test-challenge.zip
fi

# %% [markdown]
# ## Step-3: Convert to Visdrone DET data to YOLO format

# %% [markdown]
# ### Step-3.1: Clone the git repo

# %%
# !git clone https://github.com/dnautiyal/MLOps4-Capstone.git

# %% [markdown]
# ### Step-3.2: Run the convert_visdrone_DET_data_to_yolov7.py file to do the data conversion

# %%
# !python /content/MLOps4-Capstone/src/yolo_data_utils/convert_visdrone_DET_data_to_yolov7.py --output_image_size "(960, 544)"

# %%
! rm -r /content/VisDrone/VisDrone2019-DET-YOLOv7

# %% [markdown]
# ### Step-3.3: Zip the VisDrone2019-DET-YOLOv7 folder

# %%
# %%time
# %%bash
cd /content/VisDrone/VisDrone2019-DET-YOLOv7
zip -r 'VisDrone2019-DET-YOLOv7.zip' *

# %% [markdown]
# ### Step-3.4: Copy the zipped file to GDrive

# %%
# !cp "/content/VisDrone/VisDrone2019-DET-YOLOv7/VisDrone2019-DET-YOLOv7.zip" "/content/drive/MyDrive/Deepak/FourthBrain/MLOps_Course/CapstoneProject/TrainYOLOv7/data/DET_data/YOLOv7"

# %% [markdown]
# ## Step-4: Validate that the new YOLO-type annotations computed on the resized/transformed images are correct

# %%
#!rm -r /content/YOLOv7_Annotated_Images/*

# %% [markdown]
# ### Step-4.1: Run the yolo_draw_annotation_box.py file to create annotated images showing bounding boxes on the train images

# %%
# !python /content/MLOps4-Capstone/src/yolo_data_utils/yolo_draw_annotation_box.py --label_folder './VisDrone/VisDrone2019-DET-YOLOv7/train/labels' --raw_images_folder './VisDrone/VisDrone2019-DET-YOLOv7/train/images' --save_images_folder './YOLOv7_Annotated_Images/'

# %% [markdown]
# ### Step-4.2: Zip the YOLOv7_Annotated_Images folder containing annotated images

# %%
# %%time
# %%bash
zip -r 'VisDrone2019-DET-YOLOv7-AnnotatedTest.zip' '/content/YOLOv7_Annotated_Images'

# %% [markdown]
# ### Step-4.3: Copy the zipped file to GDrive

# %%
# !cp "/content/VisDrone2019-DET-YOLOv7-AnnotatedTest.zip" "/content/drive/MyDrive/Deepak/FourthBrain/MLOps_Course/CapstoneProject/TrainYOLOv7/data/DET_data/YOLOv7"
